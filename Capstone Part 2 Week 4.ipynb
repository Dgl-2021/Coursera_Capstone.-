# %% [markdown]
# ### Solving the Problem

# %%
# importing all the library
import requests 
import pandas as pd 
import numpy as np 
import random 

# module to convert an address into latitude and longitude values
# !pip install geopy
from geopy.geocoders import Nominatim 

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize


! pip install folium==0.5.0
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages/secretstorage/dhcrypto.py:16: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages/secretstorage/util.py:25: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# Requirement already satisfied: geopy in /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages (2.0.0)
# Requirement already satisfied: geographiclib<2,>=1.49 in /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages (from geopy) (1.50)
# /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages/secretstorage/dhcrypto.py:16: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages/secretstorage/util.py:25: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# Requirement already satisfied: folium==0.5.0 in /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages (0.5.0)
# Requirement already satisfied: jinja2 in /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages (from folium==0.5.0) (2.11.3)
# Requirement already satisfied: six in /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages (from folium==0.5.0) (1.15.0)
# Requirement already satisfied: requests in /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages (from folium==0.5.0) (2.22.0)
# Requirement already satisfied: branca in /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages (from folium==0.5.0) (0.4.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages (from jinja2->folium==0.5.0) (1.1.1)
# Requirement already satisfied: idna<2.9,>=2.5 in /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages (from requests->folium==0.5.0) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages (from requests->folium==0.5.0) (2021.5.30)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages (from requests->folium==0.5.0) (1.25.9)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages (from requests->folium==0.5.0) (3.0.4)
# Folium installed
# Libraries imported.

# %% [markdown]
# # Define Foursquare Credentials and Version

# %%
CLIENT_ID = 'BREHXFDT3OFGTTC24E1O323LU5IZ4HZBY5FOW0MRTHDA2LHQ' # your Foursquare ID
CLIENT_SECRET = 'DO0SJKI0BD0F01XOXV5PR1RDRCGIIZ5U5NDVHZRO4HSUPLPR' # your Foursquare Secret
ACCESS_TOKEN = 'XYFRWE52UISQAIADZLJU1K3T251A3AMVMNELVHWLEOOXQL1H' # your FourSquare Access Token
VERSION = '20180604'
LIMIT = 30
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: BREHXFDT3OFGTTC24E1O323LU5IZ4HZBY5FOW0MRTHDA2LHQ
# CLIENT_SECRET:DO0SJKI0BD0F01XOXV5PR1RDRCGIIZ5U5NDVHZRO4HSUPLPR

# %% [markdown]
# # Business Area of Interest

# %%
address = 'Baltimore'

geolocator = Nominatim(user_agent="dlowe_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 39.2908816 -76.610759

# %% [markdown]
# # Business Inquiry

# %%
search_query = 'Construction'
radius = 500
print(search_query + ' .... OK!')
# Out:
# Construction .... OK!

# %% [markdown]
#  # Search for a specific venue category

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&oauth_token={}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude,ACCESS_TOKEN, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=BREHXFDT3OFGTTC24E1O323LU5IZ4HZBY5FOW0MRTHDA2LHQ&client_secret=DO0SJKI0BD0F01XOXV5PR1RDRCGIIZ5U5NDVHZRO4HSUPLPR&ll=39.2908816,-76.610759&oauth_token=XYFRWE52UISQAIADZLJU1K3T251A3AMVMNELVHWLEOOXQL1H&v=20180604&query=Construction&radius=500&limit=30'

# %% [markdown]
# # GET Request and examine the results

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '60f9272fba62900f27e8cb82'},
#  'notifications': [{'type': 'notificationTray', 'item': {'unreadCount': 0}}],
#  'response': {'venues': [{'id': '563c5cc6cd10d06cdca0b6e7',
#     'name': 'Myrick Construction Co llc',
#     'location': {'address': 'Baltimore',
#      'lat': 39.29040206245058,
#      'lng': -76.61075592041014,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 39.29040206245058,
#        'lng': -76.61075592041014}],
#      'distance': 53,
#      'postalCode': '21229',
#      'cc': 'US',
#      'city': 'Baltimore',
#      'state': 'MD',
#      'country': 'United States',
#      'formattedAddress': ['Baltimore', 'Baltimore, MD 21229']},
#     'categories': [{'id': '5454144b498ec1f095bff2f2',
#       'name': 'Construction & Landscaping',
#       'pluralName': 'Construction & Landscaping',
#       'shortName': 'Construction',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/realestate_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1626941231',
#     'hasPerk': False},
#    {'id': '58ada730d4ab7337ff9cd646',
#     'name': 'A-1 Electrical Solutions & Construction LLC',
#     'location': {'lat': 39.289621525061136,
#      'lng': -76.61188244819641,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 39.289621525061136,
#        'lng': -76.61188244819641}],
#      'distance': 170,
#      'postalCode': '21230',
#      'cc': 'US',
#      'city': 'Baltimore',
#      'state': 'MD',
#      'country': 'United States',
#      'formattedAddress': ['Baltimore, MD 21230']},
#     'categories': [{'id': '545419b1498ea6ccd0202f58',
#       'name': 'Home Service',
#       'pluralName': 'Home Services & Repairs',
#       'shortName': 'Home Services',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/hardware_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1626941231',
#     'hasPerk': False},
#    {'id': '4c97acf094a0236aa622a912',
#     'name': 'Baltimore City Development & Construction Permit Center',
#     'location': {'address': '417 E Fayette St Ste 100',
#      'crossStreet': 'E. Fayette St. & N. Gay St.',
#      'lat': 39.290313720703125,
#      'lng': -76.60943603515625,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 39.290313720703125,
#        'lng': -76.60943603515625}],
#      'distance': 130,
#      'postalCode': '21202',
#      'cc': 'US',
#      'city': 'Baltimore',
#      'state': 'MD',
#      'country': 'United States',
#      'formattedAddress': ['417 E Fayette St Ste 100 (E. Fayette St. & N. Gay St.)',
#       'Baltimore, MD 21202']},
#     'categories': [{'id': '4bf58dd8d48988d126941735',
#       'name': 'Government Building',
#       'pluralName': 'Government Buildings',
#       'shortName': 'Government',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/government_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1626941231',
#     'hasPerk': False},
#    {'id': '5910bde851950e7aa022407d',
#     'name': 'Burrell Construction',
#     'location': {'address': '1141 Deanwood Rd',
#      'lat': 39.29091272848134,
#      'lng': -76.61392360925674,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 39.29091272848134,
#        'lng': -76.61392360925674}],
#      'distance': 272,
#      'postalCode': '21234',
#      'cc': 'US',
#      'city': 'Baltimore',
#      'state': 'MD',
#      'country': 'United States',
#      'formattedAddress': ['1141 Deanwood Rd', 'Baltimore, MD 21234']},
#     'categories': [{'id': '4bf58dd8d48988d130941735',
#       'name': 'Building',
#       'pluralName': 'Buildings',
#       'shortName': 'Building',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1626941231',
#     'hasPerk': False},
#    {'id': '4f32646519836c91c7d34e9d',
#     'name': 'Metropolitan Construction',
#     'location': {'address': '7 W Baltimore St',
#      'lat': 39.289039611816406,
#      'lng': -76.61519622802734,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 39.289039611816406,
#        'lng': -76.61519622802734}],
#      'distance': 433,
#      'postalCode': '21201',
#      'cc': 'US',
#      'city': 'Baltimore',
#      'state': 'MD',
#      'country': 'United States',
#      'formattedAddress': ['7 W Baltimore St', 'Baltimore, MD 21201']},
#     'categories': [{'id': '4d4b7105d754a06374d81259',
#       'name': 'Food',
#       'pluralName': 'Food',
#       'shortName': 'Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1626941231',
#     'hasPerk': False},
#    {'id': '518a678e498e2874ae95bbd8',
#     'name': 'M Luis construction',
#     'location': {'lat': 39.29457,
#      'lng': -76.613954,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 39.29457,
#        'lng': -76.613954}],
#      'distance': 494,
#      'cc': 'US',
#      'city': 'Baltimore',
#      'state': 'MD',
#      'country': 'United States',
#      'formattedAddress': ['Baltimore, MD']},
#     'categories': [{'id': '4bf58dd8d48988d130941735',
#       'name': 'Building',
#       'pluralName': 'Buildings',
#       'shortName': 'Building',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1626941231',
#     'hasPerk': False}]}}

# %% [markdown]
# # Get relevant part of JSON and transform it into a pandas dataframe

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
# /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages/ipykernel/__main__.py:5: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                          id  \
# 0  563c5cc6cd10d06cdca0b6e7
# 1  58ada730d4ab7337ff9cd646
# 2  4c97acf094a0236aa622a912
# 3  5910bde851950e7aa022407d
# 4  4f32646519836c91c7d34e9d
#
#                                                 name  \
# 0                         Myrick Construction Co llc
# 1        A-1 Electrical Solutions & Construction LLC
# 2  Baltimore City Development & Construction Perm...
# 3                               Burrell Construction
# 4                          Metropolitan Construction
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '5454144b498ec1f095bff2f2', 'name': 'C...  v-1626941231    False
# 1  [{'id': '545419b1498ea6ccd0202f58', 'name': 'H...  v-1626941231    False
# 2  [{'id': '4bf58dd8d48988d126941735', 'name': 'G...  v-1626941231    False
# 3  [{'id': '4bf58dd8d48988d130941735', 'name': 'B...  v-1626941231    False
# 4  [{'id': '4d4b7105d754a06374d81259', 'name': 'F...  v-1626941231    False
#
#            location.address  location.lat  location.lng  \
# 0                 Baltimore     39.290402    -76.610756
# 1                       NaN     39.289622    -76.611882
# 2  417 E Fayette St Ste 100     39.290314    -76.609436
# 3          1141 Deanwood Rd     39.290913    -76.613924
# 4          7 W Baltimore St     39.289040    -76.615196
#
#                              location.labeledLatLngs  location.distance  \
# 0  [{'label': 'display', 'lat': 39.29040206245058...                 53
# 1  [{'label': 'display', 'lat': 39.28962152506113...                170
# 2  [{'label': 'display', 'lat': 39.29031372070312...                130
# 3  [{'label': 'display', 'lat': 39.29091272848134...                272
# 4  [{'label': 'display', 'lat': 39.28903961181640...                433
#
#   location.postalCode location.cc location.city location.state  \
# 0               21229          US     Baltimore             MD
# 1               21230          US     Baltimore             MD
# 2               21202          US     Baltimore             MD
# 3               21234          US     Baltimore             MD
# 4               21201          US     Baltimore             MD
#
#   location.country                          location.formattedAddress  \
# 0    United States                   [Baltimore, Baltimore, MD 21229]
# 1    United States                              [Baltimore, MD 21230]
# 2    United States  [417 E Fayette St Ste 100 (E. Fayette St. & N....
# 3    United States            [1141 Deanwood Rd, Baltimore, MD 21234]
# 4    United States            [7 W Baltimore St, Baltimore, MD 21201]
#
#           location.crossStreet
# 0                          NaN
# 1                          NaN
# 2  E. Fayette St. & N. Gay St.
# 3                          NaN
# 4                          NaN

# %% [markdown]
# # Information of interest and filter dataframe

# %%
# keep only columns that include venue name, and anything that is associated with location

filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                                                 name  \
# 0                         Myrick Construction Co llc
# 1        A-1 Electrical Solutions & Construction LLC
# 2  Baltimore City Development & Construction Perm...
# 3                               Burrell Construction
# 4                          Metropolitan Construction
# 5                                M Luis construction
#
#                    categories                   address        lat        lng  \
# 0  Construction & Landscaping                 Baltimore  39.290402 -76.610756
# 1                Home Service                       NaN  39.289622 -76.611882
# 2         Government Building  417 E Fayette St Ste 100  39.290314 -76.609436
# 3                    Building          1141 Deanwood Rd  39.290913 -76.613924
# 4                        Food          7 W Baltimore St  39.289040 -76.615196
# 5                    Building                       NaN  39.294570 -76.613954
#
#                                       labeledLatLngs  distance postalCode  cc  \
# 0  [{'label': 'display', 'lat': 39.29040206245058...        53      21229  US
# 1  [{'label': 'display', 'lat': 39.28962152506113...       170      21230  US
# 2  [{'label': 'display', 'lat': 39.29031372070312...       130      21202  US
# 3  [{'label': 'display', 'lat': 39.29091272848134...       272      21234  US
# 4  [{'label': 'display', 'lat': 39.28903961181640...       433      21201  US
# 5  [{'label': 'display', 'lat': 39.29457, 'lng': ...       494        NaN  US
#
#         city state        country  \
# 0  Baltimore    MD  United States
# 1  Baltimore    MD  United States
# 2  Baltimore    MD  United States
# 3  Baltimore    MD  United States
# 4  Baltimore    MD  United States
# 5  Baltimore    MD  United States
#
#                                     formattedAddress  \
# 0                   [Baltimore, Baltimore, MD 21229]
# 1                              [Baltimore, MD 21230]
# 2  [417 E Fayette St Ste 100 (E. Fayette St. & N....
# 3            [1141 Deanwood Rd, Baltimore, MD 21234]
# 4            [7 W Baltimore St, Baltimore, MD 21201]
# 5                                    [Baltimore, MD]
#
#                    crossStreet                        id
# 0                          NaN  563c5cc6cd10d06cdca0b6e7
# 1                          NaN  58ada730d4ab7337ff9cd646
# 2  E. Fayette St. & N. Gay St.  4c97acf094a0236aa622a912
# 3                          NaN  5910bde851950e7aa022407d
# 4                          NaN  4f32646519836c91c7d34e9d
# 5                          NaN  518a678e498e2874ae95bbd8

# %% [markdown]
# # visualize the Construction company that are nearby

# %%
dataframe_filtered.name
# Out:
# 0                           Myrick Construction Co llc
# 1          A-1 Electrical Solutions & Construction LLC
# 2    Baltimore City Development & Construction Perm...
# 3                                 Burrell Construction
# 4                            Metropolitan Construction
# 5                                  M Luis construction
# Name: name, dtype: object

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Conrad Hotel

# add a red circle marker to represent the Conrad Hotel
folium.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Conrad Hotel',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the Italian restaurants as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%20%23map_050bd9ea201b4fe580208ae6a0969d47%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%20%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%20%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_050bd9ea201b4fe580208ae6a0969d47%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_050bd9ea201b4fe580208ae6a0969d47%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%27map_050bd9ea201b4fe580208ae6a0969d47%27%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7Bcenter%3A%20%5B39.2908816%2C-76.610759%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20zoom%3A%2013%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20%20%20 ...

# %% [markdown]
# # Explore a some Venues

# %%
venue_id = '563c5cc6cd10d06cdca0b6e7' # ID of Myrick Construction Co llc
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&oauth_token={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET,ACCESS_TOKEN, VERSION)
url
# Out:
# 'https://api.foursquare.com/v2/venues/563c5cc6cd10d06cdca0b6e7?client_id=BREHXFDT3OFGTTC24E1O323LU5IZ4HZBY5FOW0MRTHDA2LHQ&client_secret=DO0SJKI0BD0F01XOXV5PR1RDRCGIIZ5U5NDVHZRO4HSUPLPR&oauth_token=XYFRWE52UISQAIADZLJU1K3T251A3AMVMNELVHWLEOOXQL1H&v=20180604'

# %% [markdown]
# # Send get request for result

# %%
result = requests.get(url).json()
print(result['response']['venue'].keys())
result['response']['venue']
# Out:
# dict_keys(['id', 'name', 'contact', 'location', 'canonicalUrl', 'categories', 'verified', 'stats', 'likes', 'like', 'dislike', 'ok', 'allowMenuUrlEdit', 'beenHere', 'specials', 'photos', 'reasons', 'hereNow', 'createdAt', 'tips', 'shortUrl', 'timeZone', 'listed', 'seasonalHours', 'pageUpdates', 'inbox', 'attributes'])
# {'id': '563c5cc6cd10d06cdca0b6e7',
#  'name': 'Myrick Construction Co llc',
#  'contact': {'phone': '4108620202',
#   'formattedPhone': '(410) 862-0202',
#   'twitter': 'myrickconstruct'},
#  'location': {'address': 'Baltimore',
#   'lat': 39.29040206245058,
#   'lng': -76.61075592041014,
#   'labeledLatLngs': [{'label': 'display',
#     'lat': 39.29040206245058,
#     'lng': -76.61075592041014}],
#   'postalCode': '21229',
#   'cc': 'US',
#   'city': 'Baltimore',
#   'state': 'MD',
#   'country': 'United States',
#   'formattedAddress': ['Baltimore', 'Baltimore, MD 21229']},
#  'canonicalUrl': 'https://foursquare.com/v/myrick-construction-co-llc/563c5cc6cd10d06cdca0b6e7',
#  'categories': [{'id': '5454144b498ec1f095bff2f2',
#    'name': 'Construction & Landscaping',
#    'pluralName': 'Construction & Landscaping',
#    'shortName': 'Construction',
#    'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/realestate_',
#     'suffix': '.png'},
#    'primary': True}],
#  'verified': False,
#  'stats': {'tipCount': 1},
#  'likes': {'count': 0, 'groups': []},
#  'like': False,
#  'dislike': False,
#  'ok': False,
#  'allowMenuUrlEdit': True,
#  'beenHere': {'count': 0,
#   'unconfirmedCount': 0,
#   'marked': False,
#   'lastCheckinExpiredAt': 0},
#  'specials': {'count': 0, 'items': []},
#  'photos': {'count': 0, 'groups': []},
#  'reasons': {'count': 0, 'items': []},
#  'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#  'createdAt': 1446796486,
#  'tips': {'count': 1,
#   'groups': [{'type': 'following',
#     'name': 'Tips from people you follow',
#     'count': 0,
#     'items': []},
#    {'type': 'others',
#     'name': 'All tips',
#     'count': 1,
#     'items': [{'id': '5649ed1c498e8230f0a6d04b',
#       'createdAt': 1447685404,
#       'text': 'If you are looking for the one and only construction company in Baltimore, MD, then my friends look no further, because you have found it.',
#       'type': 'user',
#       'canonicalUrl': 'https://foursquare.com/item/5649ed1c498e8230f0a6d04b',
#       'likes': {'count': 0, 'groups': []},
#       'like': False,
#       'logView': True,
#       'agreeCount': 0,
#       'disagreeCount': 0,
#       'todo': {'count': 0},
#       'user': {'id': '146272042',
#        'firstName': 'David',
#        'lastName': 'Ketley',
#        'gender': 'none',
#        'countryCode': 'US',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/blank_boy.png',
#         'default': True}}}]}]},
#  'shortUrl': 'http://4sq.com/1NTakSB',
#  'timeZone': 'America/New_York',
#  'listed': {'count': 0, 'groups': []},
#  'seasonalHours': [],
#  'pageUpdates': {'count': 0, 'items': []},
#  'inbox': {'count': 0, 'items': []},
#  'attributes': {'groups': []}}

# %% [markdown]
# # Get the venue's overall rating

# %%
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# This venue has not been rated yet.

# %% [markdown]
# # No rating, let's look at another

# %%
venue_id = '5910bde851950e7aa022407d' # ID of Burrell Construction
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&oauth_token={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET,ACCESS_TOKEN, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# This venue has not been rated yet.

# %% [markdown]
# # Let's look at Tips

# %%
# After checking all 6 locations A-1 Electrical Solutions & Construction LLC has the highest tip.

venue_id = '58ada730d4ab7337ff9cd646' # ID of A-1 Electrical Solutions & Construction LLC
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&oauth_token={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET,ACCESS_TOKEN, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# This venue has not been rated yet.

# %% [markdown]
# # Get Tips

# %%
result['response']['venue']['tips']['count']
# Out:
# 2

# %% [markdown]
# # URL to get tips

# %%
## A-1 Electrical Solutions & Construction LLC

limit = 5 # set limit to be greater than or equal to the total number of tips

url = 'https://api.foursquare.com/v2/venues/{}/tips?client_id={}&client_secret={}&oauth_token={}&v={}&limit={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET,ACCESS_TOKEN, VERSION, limit)

results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '60f93d1be44e9f3a3bebdc9a'},
#  'notifications': [{'type': 'notificationTray', 'item': {'unreadCount': 0}}],
#  'response': {'tips': {'count': 2,
#    'items': [{'id': '58bff36b9900e67baccb01da',
#      'createdAt': 1488974699,
#      'text': 'I have never seen anyone handling electricity so effortlessly and with confidence. A-1 Electrical Solutions & Construction LLC`s experience really shows and the work they do is top notch.',
#      'type': 'user',
#      'canonicalUrl': 'https://foursquare.com/item/58bff36b9900e67baccb01da',
#      'likes': {'count': 0, 'groups': []},
#      'like': False,
#      'logView': True,
#      'agreeCount': 0,
#      'disagreeCount': 0,
#      'todo': {'count': 0},
#      'user': {'id': '145204820',
#       'firstName': 'Derek',
#       'lastName': 'Groce',
#       'gender': 'male',
#       'countryCode': 'BG',
#       'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#        'suffix': '/blank_boy.png',
#        'default': True}}},
#     {'id': '58bdbcdb4ca49b7a78ffda4b',
#      'createdAt': 1488829659,
#      'text': 'I had both inside and outside lights installed. All done in a very neat and tidy way.',
#      'type': 'user',
#      'canonicalUrl': 'https://foursquare.com/item/58bdbcdb4ca49b7a78ffda4b',
#      'likes': {'count': 0, 'groups': []},
#      'like': False,
#      'logView': True,
#      'agreeCount': 0,
#      'disagreeCount': 0,
#      'todo': {'count': 0},
#      'user': {'id': '46029577',
#       'firstName': 'Zenia',
#       'lastName': 'Smith',
#       'gender': 'male',
#       'countryCode': 'BG',
#       'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#        'suffix': '/blank_boy.png',
#        'default': True}}}]}}}

# %% [markdown]
# # Get tips and list of associated features

# %%
tips = results['response']['tips']['items']

tip = results['response']['tips']['items'][0]
tip.keys()
# Out:
# dict_keys(['id', 'createdAt', 'text', 'type', 'canonicalUrl', 'likes', 'like', 'logView', 'agreeCount', 'disagreeCount', 'todo', 'user'])

# %% [markdown]
# # Format column width and display all Customer tips

# %%
pd.set_option('display.max_colwidth', -1)

tips_df = json_normalize(tips) # json normalize tips

# columns to keep
filtered_columns = ['text', 'agreeCount', 'disagreeCount', 'id', 'user.firstName', 'user.lastName', 'user.id']
tips_filtered = tips_df.loc[:, filtered_columns]

# display tips
tips_filtered.reindex()
# Out:
# /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages/ipykernel/__main__.py:1: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   if __name__ == '__main__':
# /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages/ipykernel/__main__.py:3: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   app.launch_new_instance()
#                                                                                                                                                                                           text  \
# 0  I have never seen anyone handling electricity so effortlessly and with confidence. A-1 Electrical Solutions & Construction LLC`s experience really shows and the work they do is top notch.
# 1  I had both inside and outside lights installed. All done in a very neat and tidy way.
#
#    agreeCount  disagreeCount                        id user.firstName  \
# 0  0           0              58bff36b9900e67baccb01da  Derek
# 1  0           0              58bdbcdb4ca49b7a78ffda4b  Zenia
#
#   user.lastName    user.id
# 0  Groce         145204820
# 1  Smith         46029577

# %% [markdown]
# # URL, send GET request and Customer Feedback

# %%
idnumber = '46029577' # user ID with most agree counts and complete profile

url = 'https://api.foursquare.com/v2/users/{}/?client_id={}&client_secret={}&oauth_token={}&v={}'.format(idnumber,CLIENT_ID, CLIENT_SECRET, ACCESS_TOKEN,VERSION) # define URL

# send GET request
results = requests.get(url).json()

user_data=results['response']['user']['photos']['items']

#results
pd.set_option('display.max_colwidth', -1)

users_df = json_normalize(user_data)
tips_filtered
# Out:
# /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages/ipykernel/__main__.py:11: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
# /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages/ipykernel/__main__.py:13: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                                                     text  \
# 0  I had both inside and outside lights installed. All done in a very neat and tidy way.
#
#    agreeCount  disagreeCount                        id
# 0  0           0              58bdbcdb4ca49b7a78ffda4b

# %%
g=tips_df.loc[tips_df['user.id'] == '46029577']
print('First Name: ' + tips_df['user.firstName'])
print('Last Name: ' + tips_df['user.lastName'])
# Out:
# 0    First Name: Derek
# 1    First Name: Zenia
# Name: user.firstName, dtype: object
# 0    Last Name: Groce
# 1    Last Name: Smith
# Name: user.lastName, dtype: object

# %% [markdown]
# # Closer look at the customer Feedback

# %%
# define tips URL
user_id='46029577'
url = 'https://api.foursquare.com/v2/users/{}/tips?client_id={}&client_secret={}&oauth_token={}&v={}&limit={}'.format(user_id, CLIENT_ID, CLIENT_SECRET,ACCESS_TOKEN,VERSION, limit)

# send GET request and get user's tips
results = requests.get(url).json()
tips = results['response']['tips']['items']

# format column width
pd.set_option('display.max_colwidth', -1)

tips_df = json_normalize(tips)

# filter columns
filtered_columns = ['text', 'agreeCount', 'disagreeCount', 'id']
tips_filtered = tips_df.loc[:, filtered_columns]

# display user's tips
tips_filtered
# Out:
# /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages/ipykernel/__main__.py:10: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
# /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages/ipykernel/__main__.py:12: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                                                     text  \
# 0  I had both inside and outside lights installed. All done in a very neat and tidy way.
#
#    agreeCount  disagreeCount                        id
# 0  0           0              58bdbcdb4ca49b7a78ffda4b

# %% [markdown]
# # Highest Customer rating

# %%
tip_id = '58bdbcdb4ca49b7a78ffda4b' # tip id

# define URL
url = 'https://api.foursquare.com/v2/users/{}/tips?client_id={}&client_secret={}&oauth_token={}&v={}'.format(idnumber, CLIENT_ID, CLIENT_SECRET,ACCESS_TOKEN, VERSION) # define URL


# send GET Request and examine results
result = requests.get(url).json()
print(result['response']['tips']['items'][0]['venue']['name'])
print(result['response']['tips']['items'][0]['venue']['location'])
# Out:
# A-1 Electrical Solutions & Construction LLC
# {'lat': 39.289621525061136, 'lng': -76.61188244819641, 'labeledLatLngs': [{'label': 'display', 'lat': 39.289621525061136, 'lng': -76.61188244819641}], 'postalCode': '21230', 'cc': 'US', 'city': 'Baltimore', 'state': 'MD', 'country': 'United States', 'formattedAddress': ['Baltimore, MD 21230']}

# %% [markdown]
# # Explore possible location to start the business

# %%
latitude = 39.289621525061136
longitude = -76.61188244819641

# %%
url = 'https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&ll={},{}&v={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/explore?client_id=BREHXFDT3OFGTTC24E1O323LU5IZ4HZBY5FOW0MRTHDA2LHQ&client_secret=DO0SJKI0BD0F01XOXV5PR1RDRCGIIZ5U5NDVHZRO4HSUPLPR&ll=39.289621525061136,-76.61188244819641&v=20180604&radius=500&limit=30'

# %%
import requests
results = requests.get(url).json()
'There are {} around A-1 Electrical Solutions & Construction LLC.'.format(len(results['response']['groups'][0]['items']))
# Out:
# 'There are 30 around A-1 Electrical Solutions & Construction LLC.'

# %% [markdown]
# # Get relevant part of JSON

# %%
items = results['response']['groups'][0]['items']
items[0]
# Out:
# {'reasons': {'count': 0,
#   'items': [{'summary': 'This spot is popular',
#     'type': 'general',
#     'reasonName': 'globalInteractionReason'}]},
#  'venue': {'id': '4ad4c015f964a52086ef20e3',
#   'name': "Larry Flynt's Hustler Club",
#   'location': {'address': '409 E Baltimore St',
#    'lat': 39.28961547125983,
#    'lng': -76.60983330240475,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 39.28961547125983,
#      'lng': -76.60983330240475},
#     {'label': 'entrance', 'lat': 39.289655, 'lng': -76.60992}],
#    'distance': 176,
#    'postalCode': '21202',
#    'cc': 'US',
#    'city': 'Baltimore',
#    'state': 'MD',
#    'country': 'United States',
#    'formattedAddress': ['409 E Baltimore St',
#     'Baltimore, MD 21202',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d1d6941735',
#     'name': 'Strip Club',
#     'pluralName': 'Strip Clubs',
#     'shortName': 'Strip Club',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/stripclub_',
#      'suffix': '.png'},
#     'primary': True}],
#   'photos': {'count': 0, 'groups': []},
#   'venuePage': {'id': '52858696'}},
#  'referralId': 'e-0-4ad4c015f964a52086ef20e3-0'}

# %% [markdown]
# # Process JSON and convert it to a clean dataframe

# %%
dataframe = json_normalize(items) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories'] + [col for col in dataframe.columns if col.startswith('venue.location.')] + ['venue.id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# filter the category for each row
dataframe_filtered['venue.categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean columns
dataframe_filtered.columns = [col.split('.')[-1] for col in dataframe_filtered.columns]

dataframe_filtered.head(10)
# Out:
# /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages/ipykernel/__main__.py:1: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   if __name__ == '__main__':
#                                               name          categories  \
# 0  Larry Flynt's Hustler Club                       Strip Club
# 1  The Quinntessential Gentleman                    Salon / Barbershop
# 2  Under Armour Performance Center                  Clothing Store
# 3  Hotel RL Baltimore Inner Harbor                  Hotel
# 4  Chesapeake Shakespeare Company Downtown Theater  Theater
# 5  Center Club                                      Lounge
# 6  Halal Food Cart                                  Food Truck
# 7  Chez Hugo                                        French Restaurant
# 8  Kimpton Hotel Monaco Baltimore Inner Harbor      Hotel
# 9  Inner Harbor                                     Neighborhood
#
#                        address        lat        lng  \
# 0  409 E Baltimore St           39.289615 -76.609833
# 1  31 S Calvert St              39.288056 -76.612107
# 2  10 Light St                  39.289126 -76.613973
# 3  207 E Redwood St             39.288828 -76.611903
# 4  7 S Calvert St               39.288970 -76.612150
# 5  100 Light St                 39.287194 -76.613959
# 6  St Paul St & E Lexington St  39.291095 -76.613960
# 7  206 E Redwood St             39.289108 -76.611811
# 8  2 N Charles St               39.289793 -76.615647
# 9  NaN                          39.286590 -76.610704
#
#                                                                                                                              labeledLatLngs  \
# 0  [{'label': 'display', 'lat': 39.28961547125983, 'lng': -76.60983330240475}, {'label': 'entrance', 'lat': 39.289655, 'lng': -76.60992}]
# 1  [{'label': 'display', 'lat': 39.28805610001814, 'lng': -76.6121069243986}, {'label': 'entrance', 'lat': 39.288064, 'lng': -76.612084}]
# 2  [{'label': 'display', 'lat': 39.28912636166403, 'lng': -76.61397305246449}, {'label': 'entrance', 'lat': 39.289216, 'lng': -76.613909}]
# 3  [{'label': 'display', 'lat': 39.28882828237275, 'lng': -76.6119032208494}]
# 4  [{'label': 'display', 'lat': 39.288969635983165, 'lng': -76.6121501256785}]
# 5  [{'label': 'display', 'lat': 39.287193721917504, 'lng': -76.61395870380018}, {'label': 'entrance', 'lat': 39.287295, 'lng': -76.614233}]
# 6  [{'label': 'display', 'lat': 39.29109472488584, 'lng': -76.61395960981112}]
# 7  [{'label': 'display', 'lat': 39.289108, 'lng': -76.611811}]
# 8  [{'label': 'display', 'lat': 39.289793, 'lng': -76.615647}]
# 9  NaN
#
#    distance postalCode  cc       city state        country  \
# 0  176       21202      US  Baltimore  MD    United States
# 1  175       21202      US  Baltimore  MD    United States
# 2  188       21202      US  Baltimore  MD    United States
# 3  88        21202      US  Baltimore  MD    United States
# 4  76        21202      US  Baltimore  MD    United States
# 5  324       21202      US  Baltimore  MD    United States
# 6  242       21202      US  Baltimore  MD    United States
# 7  57        21202      US  Baltimore  MD    United States
# 8  324       21201      US  Baltimore  MD    United States
# 9  352       21202      US  Baltimore  MD    United States
#
#                                                                                                 formattedAddress  \
# 0  [409 E Baltimore St, Baltimore, MD 21202, United States]
# 1  [31 S Calvert St (btwn E Lombard St. & Water St.), Baltimore, MD 21202, United States]
# 2  [10 Light St, Baltimore, MD 21202, United States]
# 3  [207 E Redwood St, Baltimore, MD 21202, United States]
# 4  [7 S Calvert St (Redwood Street), Baltimore, MD 21202, United States]
# 5  [100 Light St, Baltimore, MD 21202, United States]
# 6  [St Paul St & E Lexington St (outside Clarence M Mitchell Jr Courthouse), Baltimore, MD 21202, United States]
# 7  [206 E Redwood St, Baltimore, MD 21202, United States]
# 8  [2 N Charles St (Baltimore St.), Baltimore, MD 21201, United States]
# 9  [Baltimore, MD 21202, United States]
#
#                                  crossStreet                        id
# 0  NaN                                        4ad4c015f964a52086ef20e3
# 1  btwn E Lombard St. & Water St.             4b047698f964a5205d5422e3
# 2  NaN                                        57323bb7498eaee633e7b2c6
# 3  NaN                                        5580f119498e83a40a486e8d
# 4  Redwood Street                             5410e511498ebd34b5e064f4
# 5  NaN                                        4b96d557f964a520a4e734e3
# 6  outside Clarence M Mitchell Jr Courthouse  4b8be255f964a52065b032e3
# 7  NaN                                        5a92239fe7a2371b973312a0
# 8  Baltimore St.                              4a9c2c73f964a520453620e3
# 9  NaN                                        4bae2d8cf964a5202a8e3be3

# %% [markdown]
# # Let's visualize possible business start locations

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=15) # generate map centred around A-1 Electrical Solutions & Construction LLC


# add A-1 Electrical Solutions & Construction LLC as a red circle mark
folium.CircleMarker(
    [latitude, longitude],
    radius=10,
    popup='A-1 Electrical Solutions & Construction LLC',
    fill=True,
    color='red',
    fill_color='red',
    fill_opacity=0.6
    ).add_to(venues_map)


# add popular spots to the map as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        fill=True,
        color='blue',
        fill_color='blue',
        fill_opacity=0.6
        ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%20%23map_c3adde38ffb74817b77a8a3bcc1bb089%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%20%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%20%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_c3adde38ffb74817b77a8a3bcc1bb089%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_c3adde38ffb74817b77a8a3bcc1bb089%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%27map_c3adde38ffb74817b77a8a3bcc1bb089%27%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7Bcenter%3A%20%5B39.289621525061136%2C-76.61188244819641%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20zoom%3A%2015%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%2 ...

# %% [markdown]
# # Explore Trending Venues

# %%
# define URL
url = 'https://api.foursquare.com/v2/venues/trending?client_id={}&client_secret={}&ll={},{}&v={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION)

# send GET request and get trending venues
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '60f942d0fb9fb12d51c06821'},
#  'response': {'venues': []}}

# %%
if len(results['response']['venues']) == 0:
    trending_venues_df = 'No trending venues are available at the moment!'
    
else:
    trending_venues = results['response']['venues']
    trending_venues_df = json_normalize(trending_venues)

    # filter columns
    columns_filtered = ['name', 'categories'] + ['location.distance', 'location.city', 'location.postalCode', 'location.state', 'location.country', 'location.lat', 'location.lng']
    trending_venues_df = trending_venues_df.loc[:, columns_filtered]

    # filter the category for each row
    trending_venues_df['categories'] = trending_venues_df.apply(get_category_type, axis=1)

# %%
# display trending venues
trending_venues_df
# Out:
# 'No trending venues are available at the moment!'

# %% [markdown]
# # Visualize trending venues

# %%
if len(results['response']['venues']) == 0:
    venues_map = 'Cannot generate visual as no trending venues are available at the moment!'

else:
    venues_map = folium.Map(location=[latitude, longitude], zoom_start=15) # generate map centred around Ecco


    # add Ecco as a red circle mark
    folium.CircleMarker(
        [latitude, longitude],
        radius=10,
        popup='Ecco',
        fill=True,
        color='red',
        fill_color='red',
        fill_opacity=0.6
    ).add_to(venues_map)


    # add the trending venues as blue circle markers
    for lat, lng, label in zip(trending_venues_df['location.lat'], trending_venues_df['location.lng'], trending_venues_df['name']):
        folium.CircleMarker(
            [lat, lng],
            radius=5,
            poup=label,
            fill=True,
            color='blue',
            fill_color='blue',
            fill_opacity=0.6
        ).add_to(venues_map)

# %%
# display map
venues_map
# Out:
# 'Cannot generate visual as no trending venues are available at the moment!'

# %% [markdown]
# # Thank you for reviewing my Report
