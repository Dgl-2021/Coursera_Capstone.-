# %% [markdown]
# ## Introduction
#
# #### A contractor is looking to start a new construction business in Maryland.
# #### Maryland is a state located in the Southern United States. According to the 2010 United States Census, Maryland is the 19th most populous state with 5,773,785 inhabitants and the 9th smallest by land area . The state is divided into 23 counties and contains 157 incorporated municipalities consisting of cities, towns, or villages. As Maryland does not have minor civil divisions such as townships, areas outside of municipalities have no government below the county level. This mean it a great pleace to do business and grow your business.

# %% [markdown]
# ## Business Problem
#
# #### A contractor is looking for a location to start a construction company. However, he does not have enough information about the municipalities or his competitors( other construction companies in the area) or potential partners, financical resources, etc.

# %% [markdown]
# ## Data
#
# ### The following data are used:
#
# #### Neighbourhoods(municipalities) of Maryland
# #### Geographical coordinates of the neighbourhoods
# #### Venues data around the neighbourhoods from FourSquare Neighbourhoods
# #### Data is extracted from the "List of municipalities in Maryland" Wikipedia page with URL:https://en.wikipedia.org/wiki/List_of_municipalities_in_Maryland
# #### Python BeautifulSoup library is used for web scraping
# #### Detailed list of neighbourhoods in Maryland
# #### Geographical Coordinates
# #### Python GeoPy library is used for extracting the geographical coordinates of various neighbourhoods
# #### Used for visualizing the data by plotting maps
# ### Venue Data
# #### FourSquare API is used for extracting data
# #### Used fro studying venues in various neighbourhoods
# #### Data provides the restaurant information in the area and used for drawing the conclusion

# %% [markdown]
# ## For my full Report in part 2
#
# #### I will use google API to locate all the construction company in the area, we will look up the services they offer and what are the customer feedback on those services.
#
# #### I look up the construction companies in my area and I found that they were very few. I research why there are so few constructions company in my area. Again, I used Google API, financial analysis, company review, and customer feedback to help me with my reach.
#
# #### I found that compare to the surrounding area my area provided less opportunities and no tax incentives for construction companies.
#
# #### Even though they are few construction companies in my area. The companies that are here seemed to be doing very well. I believe they are some opportunities here and a small construction company would do well. However, if the goal is to become a large company, then this might not be the best place to start a large construction company.
#
# #### Small construction company might do well in this area. However, a large construction company might not do so well in this area.
